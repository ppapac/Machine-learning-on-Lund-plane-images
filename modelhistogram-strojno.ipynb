# %%
import numpy as np
import math
import matplotlib.pyplot as plt

p = np.load('alice_mc_lorentz_jets_80_90.npy', mmap_mode='r')
labels = np.load('alice_mc_labels_80_90.npy', mmap_mode='r')
R=1
def notzero(i):
    N=0
    m=p[i][0:][0:]
    while True:
        N=N+1
        if m[N][0]<0.000001:
            break
    return p[i][0:N][0:]
        

def update(m):
    y=[0.5*math.log((m[i][0]+m[i][3])/(m[i][0]-m[i][3])) for i in range(m.shape[0])]
    pt=[np.sqrt(m[i][1]**2+m[i][2]**2) for i in range(m.shape[0])]
    azimut=[math.acos(m[i][1]/pt[i]) for i in range(m.shape[0])]
    global d
    d=np.ndarray((m.shape[0],m.shape[0]))
    for i in range(m.shape[0]):
        for j in range(m.shape[0]):
            d[i][j]=((y[i]-y[j])**2+(azimut[j]-azimut[i])**2)/R**2
        
def minimum(m):
    k=0
    l=1
    mini=m[0][1]
    for i in range(0,m.shape[0]):
        for j in range(i+1,m.shape[0]):
            if m[i][j]<mini:
                mini=m[i][j]
                k=i
                l=j
    return [k,l,mini]


def cluster(m):
    t=minimum(d)
    čestica1=t[0]
    čestica2=t[1]
    if čestica1>čestica2:
        r=čestica1
        čestica1=čestica2
        čestica2=r
    n=np.shape(m)
    b=np.ndarray((n[0]-1,4))
    s=m[čestica1]+m[čestica2]
    i=0
    j=0
    while i<m.shape[0]:
        if i==čestica1:
            b[j][:]=s
            i=i+1
            j=j+1
        elif i==čestica2:
            if i<m.shape[0]-1:
                b[j][:]=m[i+1][:]
            else:
                break
            i=i+2
            j=j+1
        else:
            b[j][:]=m[i][:]
            i=i+1
            j=j+1
    return b
                
def recluster(m):
    update(m)
    x=[]
    D=[]
    x.append(m)
    D.append(d)
    for i in range(m.shape[0]-1):
        m=cluster(m)
        update(m)
        x.append(m)
        D.append(d)
    return x,D

def decluster(x,D):
    n=len(x)
    L=[]
    i=n-2
    čes=0
    #pcut=1000
    while i>=0:
        m=minimum(D[i])
        čestica1=m[0]
        čestica2=m[1]
        if čestica2<čestica1:
            r=čestica1
            čestica1=čestica2
            čestica2=r
        if čes==čestica1:
            pt1=np.sqrt(x[i][čestica1][1]**2+x[i][čestica1][2]**2)
            pt2=np.sqrt(x[i][čestica2][1]**2+x[i][čestica2][2]**2)
            y2=0.5*math.log((x[i][čestica2][0]+x[i][čestica2][3])/(x[i][čestica2][0]-x[i][čestica2][3]))
            y1=0.5*math.log((x[i][čestica1][0]+x[i][čestica1][3])/(x[i][čestica1][0]-x[i][čestica1][3]))
            az1=math.acos(x[i][čestica1][1]/pt1)
            az2=math.acos(x[i][čestica2][1]/pt2)
            az=math.atan((y1-y2)/(az1-az2))
            
            #if pt1<pcut or pt2<pcut:
                #break
            if pt1<pt2:
                L.append([pt1*m[2],m[2],pt2*m[2],az])
                čes=čestica2
            else:
                L.append([pt2*m[2],m[2],pt1*m[2],az])
                čes=čestica1
        else:
            if čes<čestica2:
                pass
            else:
                čes=čes+1
        i=i-1
    return L

def qg(i):
    m=labels[i]
    return m

# %%
q=0
g=0
j=0
LL=[]
lb=[]
while j<500000:   
    x,D=recluster(notzero(j))
    L1=decluster(x,D)
    k1=[np.log(L1[i][0]) for i in range(len(L1))]
    d1=[np.log(1/L1[i][1]) for i in range(len(L1))]
    z=[L1[i][0]/(L1[i][0]+L1[i][2]) for i in range(len(L1))]
    yedges=[k1[i] for i in range(len(L1))]
    xedges=[d1[i] for i in range(len(L1))]
    hist,xedges,yedges=np.histogram2d(xedges,yedges,bins=len(L1),weights=z)
    hist=(hist/np.max(hist)*255).astype(int)
    LL.append(pad_image(hist))
    if labels[j]==0:
        lb.append(labels[j])
        q=q+1
    if labels[j]==1:
        lb.append(labels[j])
        g=g+1
    j=j+1
    if q>=g:
        while labels[j]!=1:
            j=j+1

# %%
q=0
g=0
j=500000
LLv=[]
lbv=[]
while j<600000:   
    x,D=recluster(notzero(j))
    L1=decluster(x,D)
    k1=[np.log(L1[i][0]) for i in range(len(L1))]
    d1=[np.log(1/L1[i][1]) for i in range(len(L1))]
    z=[L1[i][0]/(L1[i][0]+L1[i][2]) for i in range(len(L1))]
    yedges=[k1[i] for i in range(len(L1))]
    xedges=[d1[i] for i in range(len(L1))]
    hist,xedges,yedges=np.histogram2d(xedges,yedges,bins=len(L1),weights=z)
    hist=(hist/np.max(hist)*255).astype(int)
    LLv.append(pad_image(hist))
    if labels[j]==0:
        lbv.append(labels[j])
        q=q+1
    if labels[j]==1:
        lbv.append(labels[j])
        g=g+1
    j=j+1
    if q>=g:
        while labels[j]!=1:
            j=j+1

# %%
q=0
g=0
j=0
LL=[]
lb=[]
while j<500000:   
    x,D=recluster(notzero(j))
    L1=decluster(x,D)
    k1=[np.log(L1[i][0]) for i in range(len(L1))]
    d1=[np.log(1/L1[i][1]) for i in range(len(L1))]
    z=[L1[i][0]/(L1[i][0]+L1[i][2]) for i in range(len(L1))]
    dkz=[[d1[i],k1[i],z[i]] for i in range(len(L1))]
    while len(dkz)<14:
        dkz.append([0,0,0])
    LL.append(dkz)
    if labels[j]==0:
        lb.append(labels[j])
        q=q+1
    if labels[j]==1:
        lb.append(labels[j])
        g=g+1
    j=j+1
    if q>=g:
        while labels[j]!=1:
            j=j+1

# %%
q=0
g=0
j=500000
LLv=[]
lbv=[]
while j<600000:   
    x,D=recluster(notzero(j))
    L1=decluster(x,D)
    k1=[np.log(L1[i][0]) for i in range(len(L1))]
    d1=[np.log(1/L1[i][1]) for i in range(len(L1))]
    z=[L1[i][0]/(L1[i][0]+L1[i][2]) for i in range(len(L1))]
    dkz=[[d1[i],k1[i],z[i]] for i in range(len(L1))]
    while len(dkz)<14:
        dkz.append([0,0,0])
    LLv.append(dkz)
    if labels[j]==0:
        lbv.append(labels[j])
        q=q+1
    if labels[j]==1:
        lbv.append(labels[j])
        g=g+1
    j=j+1
    if q>=g:
        while labels[j]!=1:
            j=j+1

# %%
def pad_image(image, max_size = (14,14)):
    """
    Simply pad an image with zeros up to max_size.
    """
    size = np.shape(image)
    xs=np.zeros(shape=(size[0],1))
    ys=np.zeros(shape=(1,max_size[1]))
    px, py = (max_size[0]-size[0]), (max_size[1]-size[1])
    for i in range(int(np.floor(px/2.0))):
        image=np.hstack((xs,image))
    for i in range(int(np.ceil(px/2.0))):
        image=np.hstack((image,xs))
    for i in range(int(np.floor(py/2.0))):
        image=np.vstack((ys,image))
    for i in range(int(np.ceil(py/2.0))):
        image=np.vstack((image,ys))
    return image

# %%
import pickle
pickle.dump( LL, open( "trainhist.pkl", "wb" ) )
pickle.dump( lb, open( "trainlabelshist.pkl", "wb" ) )
pickle.dump( LLv, open( "valshist.pkl", "wb" ) )
pickle.dump( lbv, open( "vallabelshist.pkl", "wb" ) )

# %%
import pickle
pickle.dump( LL, open( "traintrip.pkl", "wb" ) )
pickle.dump( lb, open( "trainlabelstrip.pkl", "wb" ) )
pickle.dump( LLv, open( "valstrip.pkl", "wb" ) )
pickle.dump( lbv, open( "vallabelstrip.pkl", "wb" ) )

# %%
import pickle
LL= pickle.load( open( "trainhist.pkl", "rb" ) )
LLv= pickle.load( open( "valshist.pkl", "rb" ) )
lb= pickle.load( open( "trainlabelshist.pkl", "rb" ) )
lbv= pickle.load( open( "vallabelshist.pkl", "rb" ) )

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
batch_size = 40
train_ds=tf.data.Dataset.from_tensor_slices((LL,lb)).batch(batch_size)
val_ds=tf.data.Dataset.from_tensor_slices((LLv,lbv)).batch(batch_size)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model = Sequential([
   layers.Input(shape=(14,3)),
    layers.Flatten(),
   layers.Dense(100,activation='relu'), 
   layers.Dropout(0.5),
    layers.Dense(100, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(100,activation='relu'),
  layers.Dense(1,activation='sigmoid'),
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 42)                0
#
#  dense_8 (Dense)             (None, 100)               4300
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_9 (Dense)             (None, 100)               10100
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 24,601
# Trainable params: 24,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.00001),metrics=['accuracy'])

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
from keras.callbacks import CSVLogger

csv_logger = CSVLogger("model_history_triples.csv", append=False)

# %%
epochs=30
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',min_delta=0.001, mode='min', verbose=1,patience=7)
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
    callbacks=[es,csv_logger]
)
# Out:
# Epoch 1/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.7796 - accuracy: 0.5155 - val_loss: 0.6758 - val_accuracy: 0.5791
# Epoch 2/30
# 3400/3400 [==============================] - 5s 2ms/step - loss: 0.7136 - accuracy: 0.5289 - val_loss: 0.6752 - val_accuracy: 0.5827
# Epoch 3/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.7005 - accuracy: 0.5370 - val_loss: 0.6750 - val_accuracy: 0.5842
# Epoch 4/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6943 - accuracy: 0.5426 - val_loss: 0.6754 - val_accuracy: 0.5849
# Epoch 5/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6904 - accuracy: 0.5478 - val_loss: 0.6751 - val_accuracy: 0.5855
# Epoch 6/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6870 - accuracy: 0.5530 - val_loss: 0.6747 - val_accuracy: 0.5857
# Epoch 7/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6859 - accuracy: 0.5572 - val_loss: 0.6743 - val_accuracy: 0.5878
# Epoch 8/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6844 - accuracy: 0.5605 - val_loss: 0.6740 - val_accuracy: 0.5897
# Epoch 9/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6828 - accuracy: 0.5615 - val_loss: 0.6737 - val_accuracy: 0.5934
# Epoch 10/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6819 - accuracy: 0.5630 - val_loss: 0.6733 - val_accuracy: 0.5962
# Epoch 11/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6806 - accuracy: 0.5673 - val_loss: 0.6726 - val_accuracy: 0.5946
# Epoch 12/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6795 - accuracy: 0.5706 - val_loss: 0.6719 - val_accuracy: 0.5952
# Epoch 13/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6790 - accuracy: 0.5738 - val_loss: 0.6719 - val_accuracy: 0.5967
# Epoch 14/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6781 - accuracy: 0.5751 - val_loss: 0.6717 - val_accuracy: 0.5969
# Epoch 15/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6767 - accuracy: 0.5786 - val_loss: 0.6708 - val_accuracy: 0.5974
# Epoch 16/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6765 - accuracy: 0.5781 - val_loss: 0.6708 - val_accuracy: 0.5986
# Epoch 17/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6760 - accuracy: 0.5818 - val_loss: 0.6703 - val_accuracy: 0.5988
# Epoch 18/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6746 - accuracy: 0.5823 - val_loss: 0.6699 - val_accuracy: 0.5997
# Epoch 19/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6745 - accuracy: 0.5844 - val_loss: 0.6699 - val_accuracy: 0.6003
# Epoch 20/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6741 - accuracy: 0.5833 - val_loss: 0.6694 - val_accuracy: 0.6019
# Epoch 21/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6737 - accuracy: 0.5859 - val_loss: 0.6690 - val_accuracy: 0.6029
# Epoch 22/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6725 - accuracy: 0.5867 - val_loss: 0.6686 - val_accuracy: 0.6032
# Epoch 23/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6723 - accuracy: 0.5878 - val_loss: 0.6681 - val_accuracy: 0.6047
# Epoch 24/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6717 - accuracy: 0.5876 - val_loss: 0.6679 - val_accuracy: 0.6057
# Epoch 25/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6711 - accuracy: 0.5907 - val_loss: 0.6676 - val_accuracy: 0.6057
# Epoch 26/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6704 - accuracy: 0.5918 - val_loss: 0.6670 - val_accuracy: 0.6071
# Epoch 27/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6701 - accuracy: 0.5913 - val_loss: 0.6668 - val_accuracy: 0.6073
# Epoch 28/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6702 - accuracy: 0.5929 - val_loss: 0.6667 - val_accuracy: 0.6070
# Epoch 29/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6694 - accuracy: 0.5937 - val_loss: 0.6664 - val_accuracy: 0.6069
# Epoch 30/30
# 3400/3400 [==============================] - 6s 2ms/step - loss: 0.6693 - accuracy: 0.5930 - val_loss: 0.6666 - val_accuracy: 0.6064

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(history.history['loss']))

plt.figure(figsize=(15, 7))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save("modelhist1_strojno_trips")
# Out:
# INFO:tensorflow:Assets written to: modelhist1_strojno_trips\assets

# %%
fig = plt.figure(figsize=((25,25)))
for i in range(1,26):
    fig.add_subplot(5,5,i)
    plt.title(lb[i])
    plt.imshow(LL[i])
plt.show()
